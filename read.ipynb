# %%
import pandas as pd
df = pd.read_csv("student_dropout.csv")
inschool = df[df["Dropped_Out"] == False ]
inschool
droppedout = df[df["Dropped_Out"] == True]
droppedout
#droppedout["total"] = len(droppedout)

#1 - Age
#Dropped Out
age = droppedout.groupby("Age").agg("count").reset_index()
ageplot1= age.plot.bar(x="Age",y="Dropped_Out",title = "Ages of Students that Dropped Out")
#In School 
age2 = inschool.groupby("Age").agg("count").reset_index()
df
#ageplot2 = age2.plot.bar(x="Age",y="In_School",title = "Ages of Students In School")
#2- Gender
genderplot= droppedout.groupby("Gender").agg("count").reset_index()
genderplot1 = genderplot.plot.bar(x="Gender",y="Dropped_Out", title = "Gender of Students that Dropped Out")
#In School
gender2 = inschool.groupby("Gender").agg("count").reset_index()
genderplot2 = gender2.plot.bar(x="Gender",y="Dropped_Out",title = "Gender of Students In School")
#3 - Parental Status 
parentalplot= droppedout.groupby("Parental_Status").agg("count").reset_index()
parentalplot1 = parentalplot.plot.bar(x="Parental_Status",y="Dropped_Out", title = "Parental Status of Students that Dropped Out")
#In School
parent2 = inschool.groupby("Parental_Status").agg("count").reset_index()
parentplot2 = parent2.plot.bar(x="Parental_Status",y="Dropped_Out",title = "Parental Status of Students In School")
#4- Weekday Alcohol Constumption
wacplot = droppedout.groupby("Weekday_Alcohol_Consumption").agg("count").reset_index()
wacplot
wacplot1 = wacplot.plot.bar(x="Weekday_Alcohol_Consumption",y="Dropped_Out", title = "Weekday Alcohol Consumption of Students that Dropped Out")
# In School
wacplot2 = inschool.groupby("Weekday_Alcohol_Consumption").agg("count").reset_index()
parentplot2 = wacplot2.plot.bar(x="Weekday_Alcohol_Consumption",y="Dropped_Out",title = "Weekday Alcohol Consumption In School")
#5 - Family Support 
#Dropped Out
famSupport = droppedout.groupby("Family_Support").agg("count").reset_index()
famSupport1 = famSupport.plot.bar(x = "Family_Support", y = "Dropped_Out", title = "Family Support for Students Who Dropped Out" )
#In School
famSupport = inschool.groupby("Family_Support").agg("count").reset_index()
famSupport2 = famSupport.plot.bar(x = "Family_Support", y = "Dropped_Out" , title = "Family Support for Students Who Stayed in School")

#6 = Internet Access
#Dropped Out
internetAcc = droppedout.groupby("Internet_Access").agg("count").reset_index()
internetAcc1 = internetAcc.plot.bar(x = "Internet_Access", y = "Dropped_Out", title = "Internet Access for Students Who Dropped Out")
#In School
internetAcc = inschool.groupby("Internet_Access").agg("count").reset_index()
internetAcc2 = internetAcc.plot.bar(x = "Internet_Access", y = "Dropped_Out", title = "Internet Access for Students Who Stayed in School")

#7 = Health Status
#Dropped Out
healthStat = droppedout.groupby("Health_Status").agg("count").reset_index()
healthStat1 = healthStat.plot.bar(x = "Health_Status", y = "Dropped_Out", title = "Health Rating of the Students Who Dropped Out")
#In School
healthStat = inschool.groupby("Health_Status").agg("count").reset_index()
healthStat2 = healthStat.plot.bar(x = "Health_Status", y = "Dropped_Out", title = "Health Rating of the Students Who Stayed in School")

#8 = Weekend Alcohol Consumption
#Dropped Out
weekendAl = droppedout.groupby("Weekend_Alcohol_Consumption").agg("count").reset_index()
weekendAl1 = weekendAl.plot.bar(x = "Weekend_Alcohol_Consumption", y = "Dropped_Out", title = "Weekend Alcohol Consumption of the Students Who Dropped Out")
#In School
weekendAl = inschool.groupby("Weekend_Alcohol_Consumption").agg("count").reset_index()
weekendAl2 = weekendAl.plot.bar(x = "Weekend_Alcohol_Consumption", y = "Dropped_Out", title = "Weekend Alcohol Consumption of the Students Who Stayed in School")

#9 = Addresses
#Dropped Out
address = droppedout.groupby("Address").agg("count").reset_index()
address1 = address.plot.bar(x = "Address", y = "Dropped_Out", title = "Addresses for Students Who Dropped Out")
#In School
address = inschool.groupby("Address").agg("count").reset_index()
address2 = address.plot.bar(x = "Address", y = "Dropped_Out", title = "Addresses for Students Who Stayed in School")

#10 = Reason for Choosing School
#Dropped Out
reason = droppedout.groupby("Reason_for_Choosing_School").agg("count").reset_index()
reason1 = reason.plot.bar(x = "Reason_for_Choosing_School", y = "Dropped_Out", title = "Reason for Choosing School of Students Who Dropped Out")
#In School
reason = inschool.groupby("Reason_for_Choosing_School").agg("count").reset_index()
reason1 = reason.plot.bar(x = "Reason_for_Choosing_School", y = "Dropped_Out", title = "Reason for Choosing School of Students Who Stayed In School")
